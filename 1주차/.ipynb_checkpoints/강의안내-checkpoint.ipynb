# %% [markdown]
# ## 파이썬 프로그래밍 강의 개요

# %% [markdown]
# ### 교재 : 최신 파이썬 완전정복 기초에서 심화까지
# 1. 출판사 : 도서출판 홍릉
# 2. 저자 : 강환수, 조진형, 김유두
#
# ![image.png](attachment:f71400ef-4313-40d4-ae0a-96c5529586f1.png)

# %% [markdown]
# ### 성적 산출
# 1. 중간고사(40%), 기말고사(40%), 출석(20%)
# 2. 상대평가

# %% [markdown]
# ## 실습 환경
# - Jupyter Notebook
# - Anaconda
# - VScode
