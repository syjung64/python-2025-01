# %% [markdown]
# # Lecture 2 :  Jupyter NoteBook 개발환경

# %% [markdown]
# ### Anaconda 설치

# %% [markdown]
# ### 1. Anaconda 개요
# - **데이터 과학 및 머신러닝 환경**을 위한 오픈 소스 배포판
# - **Python 및 R** 언어를 지원하며, 다양한 라이브러리와 패키지를 쉽게 설치 및 관리
# - Jupyter Notebook, Spyder 등 **데이터 분석에 유용한 개발 도구** 포함
# - 데이터 분석, 머신러닝, 인공지능 작업을 효율적으로 수행할 수 있는 통합 환경 제공
#
# ![image.png](attachment:04ecfea0-e536-44bb-b0be-d5419ac55c04.png)

# %% [markdown]
# ### 2. Anaconda 설치
#
# ![image.png](attachment:094b7879-c3c5-4514-aab1-b2ce07bd00ea.png)

# %% [markdown]
# ### 3. Jupyter Notebook 실행

# %% [markdown]
# - **[File]-[New]-[NoteBook] 선택**
#
# ![image.png](attachment:84636792-3061-44c8-b3cc-a58bb6222472.png)
#
# - **이름 바꾸기 (Untitled -> 01-01-hello)**
#
# ![image.png](attachment:22cfedd0-e4ce-4fc6-9f5b-c2c8645b513a.png)
#
# - **코드 실행하기(01-01-hello.py / 교재 87쪽)** [Run] 또는 [Shift]-[Enter]
#
# ![image.png](attachment:14f3fac5-8c36-46b5-ba41-bd4c28efa724.png)

# %% [markdown]
# # LAB 1

# %% [markdown]
# #### 1. Jupyter NoteBook으로 다음 프로그램 작성하고 실행해 보세요
# ---
# ```python
# sum = 0
# for i in range(10):
#     sum = sum + i
# print(sum)

# %% [markdown]
# #### 2. 어떤 기능을 수행하는 프로그램인 설명해 보세요

# %% [markdown]
# #### 3. 변수 이름을 변경해 보세요.
# ---
# ```python
# 합 = 0
# for i in range(10):
#     합 = 합 + i
# print(합)

# %% [markdown]
# # LAB 2

# %% [markdown]
# #### 1. Jupyter NoteBook으로 다음 프로그램 작성하고 실행해 보세요.
# ---
# ```python
# # 라이브러리 불러오기
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # 내장된 데이터셋 불러오기 (팁 지불 데이터)
# tips = sns.load_dataset("tips")
# print(tips.head())
#
# # 1. 히스토그램(분포 그래프)
# sns.histplot(data=tips, x="total_bill", bins=20)
# plt.title("Total Bill Distribution")
# plt.show()
#
# # 2. 상관 관계 시각화(Scatter Plot)
# sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
# plt.title("Total Bill vs Tip")
# plt.show()
#
# # 3. 상자 그림(Box Plot)
# sns.boxplot(data=tips, x="day", y="total_bill", hue="sex")
# plt.title("Box Plot of Total Bill by Day and Gender")
# plt.show()
